# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Set visualization style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 8)

print("✅ Libraries imported successfully!")
# Out:
# ✅ Libraries imported successfully!

# %%
# Load all datasets
datasets = {}
raw_path = '../data/raw/'

print("📁 Available datasets:")
for f in os.listdir(raw_path):
    if f.endswith('.csv'):
        print(f"  - {f}")

# Dataset 1: Wearable Tech Sleep & Stress
try:
    df1 = pd.read_csv(raw_path + 'wearable_sleep_stress.csv')
    datasets['wearable_sleep_stress'] = df1
    print(f"\n✅ Dataset 1 loaded: {df1.shape[0]} rows, {df1.shape[1]} columns")
except Exception as e:
    print(f"\n❌ Error loading dataset 1: {e}")

# Dataset 2: Mental Health Physical Activity
try:
    df2 = pd.read_csv(raw_path + 'mental_health_physical.csv')
    datasets['mental_health_physical'] = df2
    print(f"✅ Dataset 2 loaded: {df2.shape[0]} rows, {df2.shape[1]} columns")
except Exception as e:
    print(f"❌ Error loading dataset 2: {e}")

# Dataset 3: Synthetic Mental Health
try:
    df3 = pd.read_csv(raw_path + 'synthetic_mental_health.csv')
    datasets['synthetic_mental_health'] = df3
    print(f"✅ Dataset 3 loaded: {df3.shape[0]} rows, {df3.shape[1]} columns")
except Exception as e:
    print(f"❌ Error loading dataset 3: {e}")
# Out:
# 📁 Available datasets:
#   - wearable_sleep_stress.csv
#   - lifestyle_stress.csv
#   - student_lifestyle_stress.csv
#
# ✅ Dataset 1 loaded: 10000 rows, 16 columns
# ❌ Error loading dataset 2: [Errno 2] No such file or directory: '../data/raw/mental_health_physical.csv'
# ❌ Error loading dataset 3: [Errno 2] No such file or directory: '../data/raw/synthetic_mental_health.csv'

# %%
import os

raw_path = '../data/raw/'
print("📁 Files in raw folder:")
for file in os.listdir(raw_path):
    print(f"  - {file}")
# Out:
# 📁 Files in raw folder:
#   - wearable_sleep_stress.csv
#   - 01_Data_Exploration.ipynb
#   - lifestyle_stress.csv
#   - .ipynb_checkpoints
#   - student_lifestyle_stress.csv

# %%
import os

# right path
raw_path = '../data/raw/'
print(f"Current working directory: {os.getcwd()}")
print(f"Raw path: {os.path.abspath(raw_path)}")
print(f"Does path exist? {os.path.exists(raw_path)}")

if os.path.exists(raw_path):
    print("\n📁 Files in raw folder:")
    for file in os.listdir(raw_path):
        print(f"  - {file}")
else:
    print("❌ raw folder not found! Check your directory structure.")
# Out:
# Current working directory: /Users/home/Desktop/FitSense-XAI/notebooks
# Raw path: /Users/home/Desktop/FitSense-XAI/data/raw
# Does path exist? True
#
# 📁 Files in raw folder:
#   - wearable_sleep_stress.csv
#   - 01_Data_Exploration.ipynb
#   - lifestyle_stress.csv
#   - .ipynb_checkpoints
#   - student_lifestyle_stress.csv

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Set style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 8)

print("✅ Libraries loaded!")

# Correct path (from notebooks folder)
raw_path = '../data/raw/'

# Check files
print("\n📁 Files in raw folder:")
for file in os.listdir(raw_path):
    if file.endswith('.csv'):
        print(f"  - {file}")

# Load all 3 datasets
df1 = pd.read_csv(raw_path + 'wearable_sleep_stress.csv')
df2 = pd.read_csv(raw_path + 'student_lifestyle_stress.csv')
df3 = pd.read_csv(raw_path + 'lifestyle_stress.csv')

print(f"\n✅ Wearable: {df1.shape}")
print(f"✅ Student: {df2.shape}")
print(f"✅ Lifestyle: {df3.shape}")
# Out:
# ✅ Libraries loaded!
#
# 📁 Files in raw folder:
#   - wearable_sleep_stress.csv
#   - lifestyle_stress.csv
#   - student_lifestyle_stress.csv
#
# ✅ Wearable: (10000, 16)
# ✅ Student: (25500, 9)
# ✅ Lifestyle: (1200, 7)

# %%
print("="*60)
print("STEP 2: Features & Target")
print("="*60)

# Wearable
X1 = df1_clean.drop(['User_ID', 'Daily_Stress_Level_Encoded'], axis=1)
y1 = df1_clean['Daily_Stress_Level_Encoded']

print(f"✅ Wearable: X={X1.shape}, y={y1.shape}")

# Student
X2 = df2_clean.drop(['Stress_Level'], axis=1)
y2 = df2_clean['Stress_Level']

print(f"✅ Student: X={X2.shape}, y={y2.shape}")

# Lifestyle
X3 = df3_clean.drop(['stress_level'], axis=1)
y3 = df3_clean['stress_level']

print(f"✅ Lifestyle: X={X3.shape}, y={y3.shape}")
# Out:
# ...
# STEP 2: Features & Target
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       3 print("="*60)
#       5 # Wearable
# ----> 6 X1 = df1_clean.drop(['User_ID', 'Daily_Stress_Level_Encoded'], axis=1)
#       7 y1 = df1_clean['Daily_Stress_Level_Encoded']
#       9 print(f"✅ Wearable: X={X1.shape}, y={y1.shape}")
#
# NameError: name 'df1_clean' is not defined
